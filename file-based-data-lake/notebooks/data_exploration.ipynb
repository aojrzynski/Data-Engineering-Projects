# %% [markdown]
# # Data Exploration
# ### This notebook covers the results of the pipeline. You need to run the pipeline first before running code blocks in this notebook
#
# This notebook demonstrates how to query and explore the curated datasets generated by the data pipeline.
# Using **DuckDB** to efficiently query **Parquet** files without loading them entirely into memory.

# %%
import duckdb
import os

# %%
# Define the curated data path
curated_dir = os.path.join("..", "data", "curated")

# Initialize DuckDB in-memory database
con = duckdb.connect(database=':memory:')

# %% [markdown]
# ## Query 1: Total sales by category
# This query calculates the total sales for each product category.
# The results help identify which categories contribute the most to overall sales.

# %%
# SQL query to calculate total sales by product category
query_category_sales = f"""
SELECT * FROM read_parquet('{curated_dir}/category_sales.parquet')
ORDER BY total_sales DESC;
"""
# Execute the query and fetch results into a DataFrame
category_sales_df = con.execute(query_category_sales).fetchdf()

# Styled display for Total Sales by Category
category_sales_df.style \
    .background_gradient(cmap='Blues') \
    .format({'total_sales': '£{:,.2f}'}) \
    .set_caption("Total Sales by Category") \
    .set_properties(**{'text-align': 'center'}) \
    .set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '16px'), ('font-weight', 'bold')]
    }])


# Display the results
# print("Total Sales by Category:")
# print(category_sales_df)
# Out:
# <style type="text/css">
# #T_4406f caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_4406f_row0_col0, #T_4406f_row1_col0, #T_4406f_row2_col0, #T_4406f_row3_col0 {
#   text-align: center;
# }
# #T_4406f_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_4406f_row1_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_4406f_row2_col1 {
#   background-color: #e2edf8;
#   color: #000000;
#   text-align: center;
# }
# #T_4406f_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_4406f">
#   <caption>Total Sales by Category</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4406f_level0_col0" class="col_heading level0 col0" >category</th>
#       <th id="T_4406f_level0_col1" class="col_heading level0 col1" >total_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4406f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4406f_row0_col0" class="data row0 col0" >Electronics</td>
#       <td id="T_4406f_row0_col1" class="data row0 col1" >£953,088.51</td>
#     </tr>
#     <tr>
#       <th id="T_4406f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4406f_row1_col0" class="data row1 col0" >Home Appliances</td>
#       <td id="T_4406f_row1_col1" class="data row1 col1" >£665,691.87</td>
#     </tr>
#     <tr>
#       <th id="T_4406f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4406f_row2_col0" class="data row2 col0" >Footwear</td>
#       <td id="T_4406f_row2_col1" class="data row2 col1" >£396,782.34</td>
#     </tr>
#     <tr>
#       <th id="T_4406f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4406f_row3_col0" class="data row3 col0" >Furniture</td>
#       <td id="T_4406f_row3_col1" class="data row3 col1" >£329,710.91</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Query 2: Monthly sales trends
# This query shows how total sales have changed over the last two months.
# Analyzing trends helps in forecasting future sales and identifying seasonal patterns.

# %%
# SQL query to analyze monthly sales trends
query_monthly_trends = f"""
SELECT * FROM read_parquet('{curated_dir}/monthly_sales_trend.parquet')
ORDER BY transaction_month;
"""

# Execute the query and fetch results
monthly_trends_df = con.execute(query_monthly_trends).fetchdf()

# Styled display for Monthly Sales Trends
monthly_trends_df.style \
    .bar(subset='total_sales', color='#FFA07A') \
    .format({'total_sales': '£{:,.2f}'}) \
    .set_caption("Monthly Sales Trends") \
    .set_properties(**{'text-align': 'center'}) \
    .set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '16px'), ('font-weight', 'bold')]
    }])


# Display the results
# print("\nMonthly Sales Trends:")
# print(monthly_trends_df)
# Out:
# <style type="text/css">
# #T_f4ccd caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_f4ccd_row0_col0, #T_f4ccd_row1_col0 {
#   text-align: center;
# }
# #T_f4ccd_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 100.0%, transparent 100.0%);
#   text-align: center;
# }
# #T_f4ccd_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 91.1%, transparent 91.1%);
#   text-align: center;
# }
# </style>
# <table id="T_f4ccd">
#   <caption>Monthly Sales Trends</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ccd_level0_col0" class="col_heading level0 col0" >transaction_month</th>
#       <th id="T_f4ccd_level0_col1" class="col_heading level0 col1" >total_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4ccd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4ccd_row0_col0" class="data row0 col0" >2024-12</td>
#       <td id="T_f4ccd_row0_col1" class="data row0 col1" >£1,226,959.53</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4ccd_row1_col0" class="data row1 col0" >2025-01</td>
#       <td id="T_f4ccd_row1_col1" class="data row1 col1" >£1,118,314.10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Query 3: Top 5 selling products
# This query identifies the top 5 products based on total sales.
# This insight helps in understanding customer preferences and managing inventory.

# %%
# SQL query to get top 5 selling products
query_top_products = f"""
SELECT * FROM read_parquet('{curated_dir}/top_selling_products.parquet')
ORDER BY total_sales DESC;
"""

# Execute the query and fetch results
top_products_df = con.execute(query_top_products).fetchdf()

# Styled display for Top 5 Selling Products
top_products_df.style \
    .highlight_max(subset='total_sales', color='lightgreen') \
    .format({'total_sales': '£{:,.2f}'}) \
    .set_caption("Top 5 Selling Products") \
    .set_properties(**{'text-align': 'center'}) \
    .set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '16px'), ('font-weight', 'bold')]
    }])

# Display the results
# print("\nTop 5 Selling Products:")
# print(top_products_df)
# Out:
# <style type="text/css">
# #T_556c1 caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_556c1_row0_col0, #T_556c1_row1_col0, #T_556c1_row1_col1, #T_556c1_row2_col0, #T_556c1_row2_col1, #T_556c1_row3_col0, #T_556c1_row3_col1, #T_556c1_row4_col0, #T_556c1_row4_col1 {
#   text-align: center;
# }
# #T_556c1_row0_col1 {
#   background-color: lightgreen;
#   text-align: center;
# }
# </style>
# <table id="T_556c1">
#   <caption>Top 5 Selling Products</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_556c1_level0_col0" class="col_heading level0 col0" >product</th>
#       <th id="T_556c1_level0_col1" class="col_heading level0 col1" >total_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_556c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_556c1_row0_col0" class="data row0 col0" >Sneakers</td>
#       <td id="T_556c1_row0_col1" class="data row0 col1" >£396,782.34</td>
#     </tr>
#     <tr>
#       <th id="T_556c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_556c1_row1_col0" class="data row1 col0" >Smartphone</td>
#       <td id="T_556c1_row1_col1" class="data row1 col1" >£339,626.24</td>
#     </tr>
#     <tr>
#       <th id="T_556c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_556c1_row2_col0" class="data row2 col0" >Coffee Maker</td>
#       <td id="T_556c1_row2_col1" class="data row2 col1" >£336,905.62</td>
#     </tr>
#     <tr>
#       <th id="T_556c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_556c1_row3_col0" class="data row3 col0" >Office Chair</td>
#       <td id="T_556c1_row3_col1" class="data row3 col1" >£329,710.91</td>
#     </tr>
#     <tr>
#       <th id="T_556c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_556c1_row4_col0" class="data row4 col0" >Blender</td>
#       <td id="T_556c1_row4_col1" class="data row4 col1" >£328,786.25</td>
#     </tr>
#   </tbody>
# </table>
